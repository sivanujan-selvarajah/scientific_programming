# %% [markdown]
# # Charging stations for electric vehicles

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import re
import json
import folium
import pandas as pd
import matplotlib.pyplot as plt
from urllib.request import urlopen

# Background color of graphics
# plt.style.use('dark_background')

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# /Users/sivanujanselvarajah/Documents/zhaw/4.Semester/Scientific programming/scientific_programming/Week_06/challenge

# %% [markdown]
# ### Request charging station data

# %%
# Url for server request
url = "https://data.geo.admin.ch/ch.bfe.ladestellen-elektromobilitaet/data/oicp/ch.bfe.ladestellen-elektromobilitaet.json"
  
# Request data from server
response = urlopen(url)
  
# Load data
data_orig = json.loads(response.read())

# Save the data as pandas data frame
data = pd.DataFrame(data_orig["EVSEData"])
data
# Out:
#                                        EVSEDataRecord          OperatorID  \
# 0   [{'AccessibilityLocation': 'OnStreet', 'Addres...      CH*SWISSCHARGE
# 1   [{'Accessibility': 'Paying publicly accessible...              CH*CCC
# 2   [{'Accessibility': 'Free publicly accessible',...              CH*ECU
# 3   [{'EvseID': 'CHFASE4150401', 'Accessibility': ...          CH*FASTNED
# 4   [{'deltaType': 'insert', 'lastUpdate': '2024-0...              CH*REP
# 5   [{'Accessibility': 'Free publicly accessible',...               CHEVP
# 6   [{'Accessibility': 'Restricted access', 'Acces...              CH*AIL
# 7   [{'Accessibility': 'Paying publicly accessible...   CH*ENMOBILECHARGE
# 8   [{'Accessibility': 'Paying publicly accessible...   CH*EVAEMOBILITAET
# 9   [{'Accessibility': 'Paying publicly accessible...        CH*EWACHARGE
# 10  [{'Accessibility': 'Restricted access', 'Acces...     CH*MOBILECHARGE
# 11  [{'Accessibility': 'Paying publicly accessible...  CH*MOBIMOEMOBILITY
# 12  [{'Accessibility': 'Free publicly accessible',...     CH*PACEMOBILITY
# 13  [{'Accessibility': 'Paying publicly accessible...       CH*PARKCHARGE
# 14  [{'Accessibility': 'Paying publicly accessible...          CH*SCHARGE
# 15  [{'Accessibility': 'Paying publicly accessible...              CH*TAE
# 16  [{'EvseID': 'CH*AVI*E123*0001', 'HotlinePhoneN...             CH*AVIA
# 17  [{'EvseID': 'CH*DIE*E123*0001', 'HotlinePhoneN...              CH*DIE
# 18  [{'EvseID': 'CH*EBS*E123*0004', 'HotlinePhoneN...              CH*EBS
# 19  [{'EvseID': 'CH*EWD*E123*0033', 'HotlinePhoneN...              CH*EWD
# 20  [{'EvseID': 'CH*EWO*E123*0001', 'HotlinePhoneN...              CH*EWO
# 21  [{'EvseID': 'CH*HER*E123*0001', 'HotlinePhoneN...              CH*HER
# 22  [{'EvseID': 'CH*ION*E202401', 'HotlinePhoneNum...              CH*ION
# 23  [{'EvseID': 'CH*LID*E123*0001', 'HotlinePhoneN...             CH*LIDL
# 24  [{'EvseID': 'CH*MIG*E123*0001', 'HotlinePhoneN...              CH*MIG
# 25  [{'EvseID': 'CH*TES*E123*0001', 'HotlinePhoneN...              CH*TES
# 26  [{'EvseID': 'CH*SCH*E840*9000', 'ChargingStati...              CH*SCH
# 27  [{'Accessibility': 'Restricted access', 'Addre...              CH*CPI
# 28  [{'Accessibility': 'Free publicly accessible',...              CH*SHE
#
#                       OperatorName
# 0                      Swisscharge
# 1                             Move
# 2                           eCarUp
# 3                          Fastned
# 4                      PLUG N ROLL
# 5                           evpass
# 6                              AIL
# 7                   ENMOBILECHARGE
# 8                   EVAEMOBILITAET
# 9                        EWACHARGE
# 10                    MOBILECHARGE
# 11                 MOBIMOEMOBILITY
# 12                    PACEMOBILITY
# 13                      PARKCHARGE
# 14                         SCHARGE
# 15                             TAE
# 16                            AVIA
# 17                  Stadt Dietikon
# 18                  ebs Energie AG
# 19  EWD Elektrizitätswerk Davos AG
# 20      Elektrizitätswerk Obwalden
# 21    Elektrizitätswerk Herrliberg
# 22                          IONITY
# 23                    Lidl Schweiz
# 24            Migrol Fast Charging
# 25                           Tesla
# 26                      Saascharge
# 27                     Chargepoint
# 28                  Shell Recharge

# %% [markdown]
# ### Deriving data from the operator 'evpass'

# %%
# Getting the index of evpass
idx = data[data["OperatorName"].isin(['evpass'])].index[0]
print(idx)

# Create data frame from column 'EVSEDataRecord' in the subset
df = pd.DataFrame(data.loc[idx, 'EVSEDataRecord'])
df.head()
# Out:
# 5
#               Accessibility  \
# 0  Free publicly accessible
# 1  Free publicly accessible
# 2  Free publicly accessible
# 3  Free publicly accessible
# 4  Free publicly accessible
#
#                                              Address DynamicInfoAvailable  \
# 0  {'City': 'Bussigny', 'Country': 'CHE', 'Street...                 true
# 1  {'City': 'Bussigny', 'Country': 'CHE', 'Street...                 true
# 2  {'City': 'Crans-Montana', 'Country': 'CHE', 'S...                 true
# 3  {'City': 'Crans-Montana', 'Country': 'CHE', 'S...                 true
# 4  {'City': 'Vandoeuvres', 'Country': 'CHE', 'Str...                 true
#
#       EvseID                    GeoCoordinates HotlinePhoneNumber  \
# 0    CHEVPE2  {'Google': '46.547745 6.552618'}       +41582219660
# 1   CHEVPE72  {'Google': '46.547745 6.552618'}       +41582219660
# 2   CHEVPE92  {'Google': '46.308936 7.471237'}       +41582219660
# 3   CHEVPE96  {'Google': '46.308936 7.471237'}       +41582219660
# 4  CHEVPE100  {'Google': '46.222434 6.203629'}       +41582219660
#
#    IsHubjectCompatible  IsOpen24Hours AdditionalInfo  \
# 0                 True           True           None
# 1                 True           True           None
# 2                 True           True           None
# 3                 True           True           None
# 4                 True           True           None
#
#                             AuthenticationModes  ... EnergySource  \
# 0  [REMOTE, NFC RFID Classic, NFC RFID DESFire]  ...         None
# 1  [REMOTE, NFC RFID Classic, NFC RFID DESFire]  ...         None
# 2  [REMOTE, NFC RFID Classic, NFC RFID DESFire]  ...         None
# 3  [REMOTE, NFC RFID Classic, NFC RFID DESFire]  ...         None
# 4  [REMOTE, NFC RFID Classic, NFC RFID DESFire]  ...         None
#
#   EnvironmentalImpact LocationImage SuboperatorName MaxCapacity  \
# 0                None          None            None        None
# 1                None          None            None        None
# 2                None          None            None        None
# 3                None          None            None        None
# 4                None          None            None        None
#
#   ChargingPoolID  DynamicPowerLevel HardwareManufacturer HubOperatorID  \
# 0           None               None                 None          None
# 1           None               None                 None          None
# 2           None               None                 None          None
# 3           None               None                 None          None
# 4           None               None                 None          None
#
#   AccessibilityLocation
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Take a closer look at the coordinates

# %%
# Look at the geo-coordinates (latitude and longitude)
coordinates = df.GeoCoordinates
print(type(coordinates))
print(coordinates)

# Look at the type of a single item in the data frame
print(type(coordinates[0]))
# Out:
# <class 'pandas.core.series.Series'>
# 0       {'Google': '46.547745 6.552618'}
# 1       {'Google': '46.547745 6.552618'}
# 2       {'Google': '46.308936 7.471237'}
# 3       {'Google': '46.308936 7.471237'}
# 4       {'Google': '46.222434 6.203629'}
#                       ...
# 3185      {'Google': '46.38416 6.24539'}
# 3186      {'Google': '46.38418 6.24537'}
# 3187      {'Google': '47.5024 8.031475'}
# 3188    {'Google': '46.035701 8.919653'}
# 3189    {'Google': '46.035701 8.919653'}
# Name: GeoCoordinates, Length: 3190, dtype: object
# <class 'dict'>

# %% [markdown]
# ### Extracting the latitude and longitude

# %%
# Getting single values from as string
coord_str = "".join(coordinates[0].values())
coord_str 

# Splitting string by white space
re.findall(r'\S+', coord_str)
# Out:
# ['46.547745', '6.552618']

# %% [markdown]
# ### Using a for loop to write the latitude and longitude to a separate data frame

# %%
# Now loop though the coordinates object
out_list = []

for i in coordinates:
    # Getting single values from as string
    coord_str = "".join(i.values())
    # Splitting string by white space
    coords = re.findall(r'\S+', coord_str)
    out_list.append(coords)

# Create data frame from the list
df = pd.DataFrame(out_list, columns =['lat', 'lon'])
print(df.dtypes)

# Here we still have strings which need to be converted to integers

# First: exclude white space using pythons lambda function
df['lat'] = df['lat'].apply(lambda x: x.strip())
df['lon'] = df['lon'].apply(lambda x: x.strip())

# Second: cange to integer values
df['lat'] = df['lat'].astype(float)
df['lon'] =  df['lon'].astype(float)
df
# Out:
# lat    object
# lon    object
# dtype: object
#             lat       lon
# 0     46.547745  6.552618
# 1     46.547745  6.552618
# 2     46.308936  7.471237
# 3     46.308936  7.471237
# 4     46.222434  6.203629
# ...         ...       ...
# 3185  46.384160  6.245390
# 3186  46.384180  6.245370
# 3187  47.502400  8.031475
# 3188  46.035701  8.919653
# 3189  46.035701  8.919653
#
# [3190 rows x 2 columns]

# %% [markdown]
# ### Plot the charging stations of the operator 'evepass'

# %%
# Subset of gas stations by brand
locations = df[["lat", "lon"]]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]]).add_to(map)

# Plot map
map
# Out:
#          lat       lon
# 0  46.547745  6.552618
# 1  46.547745  6.552618
# 2  46.308936  7.471237
# 3  46.308936  7.471237
# 4  46.222434  6.203629
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9421a835ecc15d55178f475628b501c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9421a835ecc15d55178f475628b501c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9421a835ecc15d55178f475628b501c9 = L.map(
#                 &quot;map_9421a835ecc15d55178f475628b501c9&quot;,
#                 {
#                     center: [46.6120473445141, 7.6203896946708465],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#
#
#
#             var tile_layer_226b9c77df86a41f7fc86dc89103edd8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_226b9c77df86a41f7fc86dc89103edd8.addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_91ec638fcc91a2a7db7d65b3b9d453a9 = L.marker(
#                 [46.547745, 6.552618],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_573b60383c0c308a13e9eea4d5803773 = L.marker(
#                 [46.547745, 6.552618],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_455a5921f301bb468dc966c08cefb119 = L.marker(
#                 [46.308936, 7.471237],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_8642f85970e986702371f85fb1fbc2b1 = L.marker(
#                 [46.308936, 7.471237],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_79e114e42abeb427a015043b592e5c2c = L.marker(
#                 [46.222434, 6.203629],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_6e0f02748712f82b25c404234a1bb7bc = L.marker(
#                 [46.222434, 6.203629],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_a55e7eb2da2fa7499847c85ba1efb2fc = L.marker(
#                 [46.986632, 6.915839],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_739de22b510467dd407d9639bbf863c9 = L.marker(
#                 [46.986632, 6.915839],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_65ff9b03ca332efac8cb6cd173afcce6 = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_f56579bc478937f13cd4aad0958332ad = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_0548826c75381657579e90a459f26388 = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_4392a37944cd461ab3880dbe4ff3d8dc = L.marker(
#                 [46.233099, 7.357062],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_d8df0f39d18ced441a3dd6f2cb7ba10c = L.marker(
#                 [46.991985, 6.932756],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_767f8144d7635bea5fd92116e5fd0a4b = L.marker(
#                 [46.432706, 6.909928],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_64282c12847b1aa77c978afe619b686b = L.marker(
#                 [47.369084, 8.547989],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_f3b06deca477b80fe2b24ae9ad75a531 = L.marker(
#                 [47.369084, 8.547989],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_a4c940d4ccd404a1f520a344a2d75833 = L.marker(
#                 [47.369084, 8.547989],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_67d487c52bdcb3680c54deab5d31f22f = L.marker(
#                 [46.21186, 6.173321],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_0b26504ba917a29f36be1f1d43124d2c = L.marker(
#                 [46.187209, 6.128166],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_e0982a77fb394cdbee94bfd76198b891 = L.marker(
#                 [46.21186, 6.173321],
#                 {}
#             ).addTo(map_9421a835ecc15d55178f475628b501c9);
#
#
#             var marker_8a5677d5635d5d8d8aed7af12fa7024e = L.marker(

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Darwin | 23.3.0
# Datetime: 2024-04-03 16:07:22
# Python Version: 3.10.13
# -----------------------------------
